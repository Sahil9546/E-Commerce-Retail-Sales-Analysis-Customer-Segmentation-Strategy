# %% [markdown]
# # E-Commerce Retail Sales Analysis & Customer Segmentation
# This notebook contains the complete data cleaning, feature engineering, RFM modeling, and exploratory analysis.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# Load dataset
df = pd.read_csv('../Data/OnlineRetail.csv')
df.head()
